# %%
import os
import pandas as pd

# %%
path = "Pandas-Data-Science-Tasks-master\SalesAnalysis\Sales_Data"
files = [file for file in os.listdir(path) if not file.startswith('.')] # Ignore hidden files

all_months_data = pd.DataFrame()

for file in files:
    current_data = pd.read_csv(path+"/"+file)
    all_months_data = pd.concat([all_months_data, current_data])
    
all_months_data.to_csv("all_data.csv", index=False)

# %%
all_data = pd.read_csv("all_data.csv")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#         Order Date                      Purchase Address
# 0   4/19/2019 8:46          917 1st St, Dallas, TX 75001
# 1   4/7/2019 22:30     682 Chestnut St, Boston, MA 02215
# 2  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4   4/30/2019 9:27     333 8th St, Los Angeles, CA 90001

# %%
all_data.idxmax()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-f205d56cf51a> in <module>
# ----> 1 all_data.idxmax()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in idxmax(self, axis, skipna)
#    9070         axis = self._get_axis_number(axis)
#    9071
# -> 9072         res = self._reduce(
#    9073             nanops.nanargmax, "argmax", axis=axis, skipna=skipna, numeric_only=False
#    9074         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    8849             # After possibly _get_data and transposing, we are now in the
#    8850             #  simple case where we can use BlockManager.reduce
# -> 8851             res, _ = df._mgr.reduce(blk_func, ignore_failures=ignore_failures)
#    8852             out = df._constructor(res).iloc[0]
#    8853             if out_dtype is not None:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in reduce(self, func, ignore_failures)
#     352         res_blocks: List[Block] = []
#     353         for blk in self.blocks:
# --> 354             nbs = blk.reduce(func, ignore_failures)
#     355             res_blocks.extend(nbs)
#     356
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in reduce(self, func, ignore_failures)
#    2540                 return func(values)
#    2541
# -> 2542             return self.split_and_operate(
#    2543                 None, mask_func, False, ignore_failures=ignore_failures
#    2544             )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in split_and_operate(self, mask, f, inplace, ignore_failures)
#     531                 #  reduction that is dropping nuisance columns GH#37827
#     532                 try:
# --> 533                     nv = f(m, v, i)
#     534                 except TypeError:
#     535                     if ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in mask_func(mask, values, inplace)
#    2538                 if values.ndim == 1:
#    2539                     values = values.reshape(1, -1)
# -> 2540                 return func(values)
#    2541
#    2542             return self.split_and_operate(
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in blk_func(values)
#    8821                 return values._reduce(name, skipna=skipna, **kwds)
#    8822             else:
# -> 8823                 return op(values, axis=1, skipna=skipna, **kwds)
#    8824
#    8825         def _get_data() -> DataFrame:
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      66             if any(self.check(obj) for obj in obj_iter):
#      67                 f_name = f.__name__.replace("nan", "")
# ---> 68                 raise TypeError(
#      69                     f"reduction operation '{f_name}' not allowed for this dtype"
#      70                 )
#
# TypeError: reduction operation 'argmax' not allowed for this dtype

# %%
# Find NAN
nan_df = all_data[all_data.isna().any(axis=1)]
display(nan_df.head())

all_data = all_data.dropna(how='all')
all_data.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 355       NaN     NaN              NaN        NaN        NaN              NaN
# 734       NaN     NaN              NaN        NaN        NaN              NaN
# 1432      NaN     NaN              NaN        NaN        NaN              NaN
# 1552      NaN     NaN              NaN        NaN        NaN              NaN
# 1570      NaN     NaN              NaN        NaN        NaN              NaN
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#         Order Date                      Purchase Address
# 0   4/19/2019 8:46          917 1st St, Dallas, TX 75001
# 1   4/7/2019 22:30     682 Chestnut St, Boston, MA 02215
# 2  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001
# 4   4/30/2019 9:27     333 8th St, Los Angeles, CA 90001

# %%
all_data = all_data[all_data['Order Date'].str[0:2]!='Or']

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %%
all_data['Month'] =pd.to_datetime(all_data['Order Date'],errors='coerce').dt.month
all_data.sample(10)
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 141318   282810        USB-C Charging Cable                 1       11.95
# 5407     181729    Apple Airpods Headphones                 1      150.00
# 29715    247511  Bose SoundSport Headphones                 1       99.99
# 30135    247908            27in FHD Monitor                 1      149.99
# 105485   162218    Apple Airpods Headphones                 1      150.00
# 10027    186128       AA Batteries (4-pack)                 1        3.84
# 49115    313550    Apple Airpods Headphones                 1      150.00
# 163349   267533    Lightning Charging Cable                 2       14.95
# 47276    311799       AA Batteries (4-pack)                 1        3.84
# 114420   170754            27in FHD Monitor                 1      149.99
#
#              Order Date                         Purchase Address  Month
# 141318   11/14/19 07:52  385 Hickory St, San Francisco, CA 94016     11
# 5407     4/5/2019 21:34          940 Maple St, Seattle, WA 98101      4
# 29715    08/16/19 19:53    262 South St, San Francisco, CA 94016      8
# 30135    08/01/19 11:49  736 Jackson St, San Francisco, CA 94016      8
# 105485   03/05/19 19:53    115 Madison St, Los Angeles, CA 90001      3
# 10027   4/10/2019 18:29       919 Park St, Los Angeles, CA 90001      4
# 49115    12/26/19 11:18            876 13th St, Dallas, TX 75001     12
# 163349   10/23/19 10:12   865 Lakeview St, Los Angeles, CA 90001     10
# 47276    12/20/19 12:12             48 Park St, Austin, TX 73301     12
# 114420   03/06/19 10:06     652 West St, San Francisco, CA 94016      3

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_state(address):
    return address.split(",")[2].split(" ")[1]

all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#         Order Date                      Purchase Address  Month  \
# 0   4/19/2019 8:46          917 1st St, Dallas, TX 75001      4
# 1   4/7/2019 22:30     682 Chestnut St, Boston, MA 02215      4
# 2  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 3  4/12/2019 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4   4/30/2019 9:27     333 8th St, Los Angeles, CA 90001      4
#
#                 City
# 0       Dallas  (TX)
# 1       Boston  (MA)
# 2  Los Angeles  (CA)
# 3  Los Angeles  (CA)
# 4  Los Angeles  (CA)

# %%
all_data['Sales'] = all_data['Quantity Ordered'].astype('int') * all_data['Price Each'].astype('float')

# %%
all_data.corr()
# Out:
#                   Quantity Ordered  Price Each     Month     Sales
# Quantity Ordered          1.000000   -0.148272  0.000791 -0.139417
# Price Each               -0.148272    1.000000 -0.003375  0.999203
# Month                     0.000791   -0.003375  1.000000 -0.003466
# Sales                    -0.139417    0.999203 -0.003466  1.000000

# %%
all_data.groupby(['Month']).sum()
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
import matplotlib.pyplot as plt

months = range(1,13)
print(months)

plt.bar(months,all_data.groupby(['Month']).sum()['Sales'])
plt.xticks(months)
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.show()
# Out:
# range(1, 13)

# %%
import matplotlib.pyplot as plt

keys = [city for city, df in all_data.groupby(['City'])]

plt.bar(keys,all_data.groupby(['City']).sum()['Sales'])
plt.ylabel('Sales in USD ($)')
plt.xlabel('Month number')
plt.xticks(keys, rotation='vertical', size=8)

plt.show()
